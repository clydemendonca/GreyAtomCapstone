# %% [markdown]
# # Capstone Project
# ## Segment the audience of a content app based on its user’s propensity to watch a video in the next 2 days
#
# ### Index
# - [Package Imports](#package-imports)
# - EDA
#     - [EDA for AppInstalled Dataset](#eda-app-installed)
#     - [EDA for AppUninstalled Dataset](#eda-app-uninstalled)
#     - [EDA for Registration Dataset](#registration)
#     - [EDA for UTMVisited Dataset](#eda-utm-visited)
#     - [EDA for VideoDetails Dataset](#eda-video-details)
#     - [EDA for VideoStarted Dataset](#eda-video-started)

# %% [markdown]
# <a id="package-imports"></a>
# # Package Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import numpy as np

sns.set(style="darkgrid")

# %% [markdown]
# <a id="eda-app-installed"></a>
# # EDA for App Installed

# %%
df_applaunched = pd.read_csv("./Data/AppLaunched.csv")

# %%
list(df_applaunched)
# Out:
# ['UserId',
#  'Date',
#  'Minute_Of_Day',
#  'Second',
#  'State',
#  'Country',
#  'Device',
#  'OS']

# %%
#Exploring the 'Country' column of AppLaunched Data.
df_applaunched_country = pd.DataFrame(df_applaunched['Country'].value_counts())
#Selecting only the country which have high counts of users launching the application
df_applaunched_country = df_applaunched_country[df_applaunched_country['Country']>50000]
#Visualizing using the bar plot
ax = sns.barplot(x=df_applaunched_country.index,y=df_applaunched_country['Country'])
ax.set_xticklabels(['1','40','Unknown(255)'], rotation='horizontal', fontsize=10)
# Out:
# [Text(0,0,'1'), Text(0,0,'40'), Text(0,0,'Unknown(255)')]

# %%
#Exploring the 'State' column of AppLaunched Data.
df_applaunched_state = pd.DataFrame(df_applaunched['State'].value_counts())
#Selecting only the states which have high counts of users launching the application
df_applaunched_state = df_applaunched_state[df_applaunched_state['State']>100000]
#Visualizing using the bar plot
ax = sns.barplot(x=df_applaunched_state.index,y=df_applaunched_state['State'])

# %%
#Exploring the 'Device' column of AppLaunched Data.
df_applaunched_device = pd.DataFrame(df_applaunched['Device'].value_counts())
#Selecting only the devices which have high counts of users launching the application
df_applaunched_device = df_applaunched_device[df_applaunched_device['Device']>0]
#Visualizing using the bar plot
ax = sns.barplot(x=df_applaunched_device.index,y=df_applaunched_device['Device'])
ax.set_xticklabels(['Desktop(0)','Mobile(1)','Tablet(2)','TV(3)'], rotation='horizontal', fontsize=10)
# Out:
# [Text(0,0,'Desktop(0)'),
#  Text(0,0,'Mobile(1)'),
#  Text(0,0,'Tablet(2)'),
#  Text(0,0,'TV(3)')]

# %%
#Exploring the 'OS' column of AppLaunched Data.
df_applaunched_OS = pd.DataFrame(df_applaunched['OS'].value_counts())
#Selecting only the devices which have high counts of users launching the application
df_applaunched_OS = df_applaunched_OS[df_applaunched_OS['OS']>0]
#Visualizing using the bar plot
ax = sns.barplot(x=df_applaunched_OS.index,y=df_applaunched_OS['OS'])
ax.set_xticklabels(['Others(0)','Android(1)','iOS(2)'], rotation='horizontal', fontsize=10)
# Out:
# [Text(0,0,'Others(0)'), Text(0,0,'Android(1)'), Text(0,0,'iOS(2)')]

# %%
#Starting with date & time of day columns of AppLaunched data
#Splitting the date column into month & day
df_applaunched['Date_time'] = pd.to_datetime(df_applaunched['Date'],format="%Y%m%d")
df_applaunched['month'] = df_applaunched['Date_time'].dt.strftime('%b')
df_applaunched['day_of_month']= df_applaunched['Date_time'].dt.day

# %%
#Grouping by month & day, aggregating based on count for each day of each month
df_groupedby_month_and_day = df_applaunched.groupby(by=['month','day_of_month']).count().reset_index()

# %%
#df_groupedby_month_and_day

# %%
#Plotting the stacked line chart for each month
plt.figure(figsize=(16, 7))
sns.pointplot(x="day_of_month", y="UserId", hue="month", data=df_groupedby_month_and_day)
plt.xlabel("Day of Month")
plt.ylabel("No. of AppLaunches")
plt.title("VARIATION IN APP LAUNCHES DAILY FROM JAN TO MAY")
plt.legend(loc='upper right')

# %%
def make_timestamp(row):
    date_as_string = str(row['Date'])
    hour = str(row['Minute_Of_Day'] // (60))
    minute = str(row['Minute_Of_Day'] % 60)
    
    if len(hour) == 1:
        hour = '0' + hour
        
    if len(minute) == 1:
        minute = '0' + minute
    
    date_string = date_as_string[:4] + '-' + date_as_string[4:6] + '-' + date_as_string[6:] + ' ' + hour + ':' + minute
    datetime_object = datetime.strptime(date_string, '%Y-%m-%d %H:%M')
    return datetime_object

# %%
df_applaunched['TimeStamp'] = df_applaunched.apply(make_timestamp,axis=1)

# %%
df_applaunched['TimeStamp'].head()
# Out:
# 0   2017-01-06
# 1   2017-01-06
# 2   2017-01-06
# 3   2017-01-06
# 4   2017-01-06
# Name: TimeStamp, dtype: datetime64[ns]

# %% [markdown]
# <a id="eda-app-uninstalled"></a>
# # EDA for App Uninstalled

# %%
app_uninstalled_df = pd.read_csv('./Data/AppUninstalled.csv')

# %%
app_uninstalled_df["UserId"].value_counts().head()
# Out:
# 93d087d8b7df56f94b963367c640d557    41
# 64baef3964258bdead9ed9e4a1df84dc    31
# ebaed4942c8e92e124afbad8720e7021    20
# 00777fb8db3ca4b63736934f698d905e    19
# 931edc94a53bddd1ad54759242b6c19c    18
# Name: UserId, dtype: int64

# %%
app_uninstalled_df["Date"].value_counts().head()
# Out:
# 20170122    3288
# 20170605    3265
# 20170607    3160
# 20170522    3065
# 20170124    3059
# Name: Date, dtype: int64

# %%
app_uninstalled_df["Minute_Of_Day"].value_counts().head()
# Out:
# 178    9922
# 132    9440
# 174    9315
# 142    9090
# 124    8141
# Name: Minute_Of_Day, dtype: int64

# %%
app_uninstalled_df["Second"].value_counts()
# Out:
# 0    326684
# Name: Second, dtype: int64

# %%
app_uninstalled_df["State"].value_counts().head()
# Out:
# 35     81285
# 0      37630
# 40     25018
# 57     24382
# 160    24070
# Name: State, dtype: int64

# %%
app_uninstalled_df["Country"].value_counts().head()
# Out:
# 1      196884
# 40      88374
# 255     37425
# 14       1950
# 2         737
# Name: Country, dtype: int64

# %%
app_uninstalled_df["Device"].value_counts()
# Out:
# 1    308815
# 2     16025
# 0      1696
# 3       148
# Name: Device, dtype: int64

# %%
app_uninstalled_df["OS"].value_counts()
# Out:
# 1    310736
# 2     14618
# 0      1330
# Name: OS, dtype: int64

# %%
app_uninstalled_df.dtypes
# Out:
# UserId           object
# Date              int64
# Minute_Of_Day     int64
# Second            int64
# State             int64
# Country           int64
# Device            int64
# OS                int64
# dtype: object

# %%
# Check for 0s in numerical columns

# %%
numeric_df = app_uninstalled_df._get_numeric_data()
numeric_df_is_zero = numeric_df.isin([0])

# %%
for column in numeric_df_is_zero.columns:
    print(column)
    print(numeric_df_is_zero[column].value_counts())
    print('________________________________')
# Out:
# Date
# False    326684
# Name: Date, dtype: int64
# ________________________________
# Minute_Of_Day
# False    326612
# True         72
# Name: Minute_Of_Day, dtype: int64
# ________________________________
# Second
# True    326684
# Name: Second, dtype: int64
# ________________________________
# State
# False    289054
# True      37630
# Name: State, dtype: int64
# ________________________________
# Country
# False    326489
# True        195
# Name: Country, dtype: int64
# ________________________________
# Device
# False    324988
# True       1696
# Name: Device, dtype: int64
# ________________________________
# OS
# False    325354
# True       1330
# Name: OS, dtype: int64
# ________________________________

# %%
app_uninstalled_df.describe()
# Out:
#                Date  Minute_Of_Day    Second          State        Country  \
# count  3.266840e+05  326684.000000  326684.0  326684.000000  326684.000000
# mean   2.017035e+07     357.310704       0.0      41.461327      40.816655
# std    1.648711e+02     401.987829       0.0      37.381092      78.878149
# min    2.017011e+07       0.000000       0.0       0.000000       0.000000
# 25%    2.017021e+07     138.000000       0.0      33.000000       1.000000
# 50%    2.017040e+07     157.000000       0.0      35.000000       1.000000
# 75%    2.017051e+07     178.000000       0.0      43.000000      40.000000
# max    2.017061e+07    1439.000000       0.0     252.000000     255.000000
#
#               Device             OS
# count  326684.000000  326684.000000
# mean        1.044768       1.040675
# std         0.232493       0.217172
# min         0.000000       0.000000
# 25%         1.000000       1.000000
# 50%         1.000000       1.000000
# 75%         1.000000       1.000000
# max         3.000000       2.000000

# %%
app_uninstalled_df["UserId"].value_counts().nlargest(10).plot(kind = "bar")

# %%
app_uninstalled_df["UserId"].value_counts().nlargest(50).plot(kind = "bar")

# %%
app_uninstalled_df["Device"].value_counts().plot.pie(autopct="%.2f")

# %%
app_uninstalled_df["Country"].value_counts().plot.pie(autopct="%.2f")

# %%
g = sns.lmplot("Device","Country",app_uninstalled_df)
# Out:
# /Users/Clyde/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.scatter(app_uninstalled_df["Device"],app_uninstalled_df["OS"])

# %% [markdown]
# # Timestamp conversion for App Uninstalled Dataset

# %%
app_uninstalled_df['TimeStamp']= app_uninstalled_df["Date"].astype(str)+" "+(app_uninstalled_df['Minute_Of_Day']//60).astype(str) +":"+ (app_uninstalled_df['Minute_Of_Day']%60).astype(str)+ ":"+app_uninstalled_df["Second"].astype(str)

# %%
app_uninstalled_df['TimeStamp']=pd.to_datetime(app_uninstalled_df["TimeStamp"],format="%Y%m%d %H:%M:%S")
app_uninstalled_df["TimeStamp"].head()
# Out:
# 0   2017-01-06 00:00:00
# 1   2017-01-06 00:00:00
# 2   2017-01-06 00:01:00
# 3   2017-01-06 00:01:00
# 4   2017-01-06 00:06:00
# Name: TimeStamp, dtype: datetime64[ns]

# %% [markdown]
# <a id="registration"></a>
# # EDA for Registration

# %%
registration_df = pd.read_csv('./Data/Registration.csv')

# %%
registration_df.head()
# Out:
#                              UserId      Date  Minute_Of_Day  Second  State  \
# 0  d168e2b924124feaad13eae44a68fce9  20170106              0       8     35
# 1  deed7490952a6746610ee2ee9fd219b7  20170106              0       8      7
# 2  13d9f55e297d7d9c219fbe9085e1006c  20170106              0      28     35
# 3  fccc2c0abf5afabf242a70df7b4c9e69  20170106              0      52     39
# 4  9ff982b29d78cefc8eb5a3ffb7fd2a5d  20170106              0      52     38
#
#    Country  Device  OS         Status
# 0        1       1   2       Complete
# 1       40       1   1      Completed
# 2        1       1   2       Complete
# 3        1       1   1      Completed
# 4        1       1   1  Not Completed

# %%
registration_df.shape
# Out:
# (329579, 9)

# %%
columns_for_describing = [
    'Date',
    'Minute_Of_Day',
    'Second'
]

registration_df[columns_for_describing].describe()
# Out:
#                Date  Minute_Of_Day         Second
# count  3.295790e+05  329579.000000  329579.000000
# mean   2.017039e+07     859.484913      27.907603
# std    1.517299e+02     381.084623      17.306101
# min    2.017011e+07       0.000000       0.000000
# 25%    2.017031e+07     612.000000      12.000000
# 50%    2.017042e+07     899.000000      28.000000
# 75%    2.017052e+07    1180.000000      44.000000
# max    2.017061e+07    1439.000000      56.000000

# %%
registration_df = registration_df.replace('Complete', 'Completed')

# %%
columns_for_value_counts = [
    'UserId',
    'Country',
    'Device',
    'OS',
    'Status',
    'State'
]

for column in columns_for_value_counts:
    print('==========================================================')
    print('Column: ' + column)
    print(registration_df[column].value_counts())
# Out:
# ==========================================================
# Column: UserId
# 8bbb1c03eae7ff6d8523dda861e27045    546
# b2c763b19151732ccdc108a790ed273f     65
# 6bfd2ce12162d39c635b9df4b42c874a     47
# 40cc9472bdaf0d4df83a51d93c20aca1     43
# c519adb3903b3d83c46dcf05a9db441a     43
# f6f20d83c94c124c4790454593fd4c96     43
# 757e76a31d57178a42cc0157e6c32048     42
# 5b3d76d28925459f99dc05526168a374     34
# 0fdf99107000dc0e2084a8668d8acb28     34
# d3f60900ea03d43c009089da47d73898     29
# 2dead7dd1caac504a9310b459c83d3bc     27
# 608a1ad851a9fc9113c7cba938b3741b     27
# c43173689a9a5da27d09beed18979e73     25
# befe5a9cd11684824f9763a9fc755075     24
# 239644e1f91fadba5a21d3fa9ec83e28     23
# ca630d146604b80d461827f85ed059e9     22
# 48785888a2593da8b98daade1d2ecd54     22
# 7c0599c69d9451af9401055717d26f22     22
# c9d4b265dfaf29aa2bd7d165c2261ac7     21
# 5158897d35b65b6d401e4d46d91d43dc     21
# 379822aae47fe301c7b8f6bdb6658063     20
# d6e387358065d6f7dea5676b6456a1f1     20
# 32bfcd15d79a2ae376085dd15f76cee1     19
# 4c5806735d29492c2226c9a711d4b1c8     19
# 3a60c53ee1a2edcd8f66a331a5a5e2b8     19
# 18914038b511376018c196e9eb7d1182     18
# b29b5693eab25d00bd5f493a2e014a20     18
# 8d4a0cd795b3bfda0883f02d07cf5d97     18
# 7d29cd0e706d16dce3a46a659be3e1a0     18
# 8b5568960845ee918cb8e95752bb4a95     18
#                                    ...
# b6c015710622433d53f2011da024679c      1
# f40982cf9cf221e8aea35f7e4d16c9aa      1
# 858dd448822d23b1a5b7750a1fc0abaa      1
# 4153252d56bcfb30fa6db5e8e054226c      1
# 40f18fedb5d85948eccdff674dba5d5b      1
# 8257b013228a6c933d0e33c8310276e1      1
# 321d82c16b38d69ec20b8e85a2c84e14      1
# a8c01d082d9a693fa917228b3c48134f      1
# bfde9daec431689feee924328154857f      1
# 09734d6fb864e13736baeb4d152a9aae      1
# 216ce89e3efb042f336c398d4e5089ff      1
# 3ff391a239072c0d797782ba7f1bf10a      1
# 4ecb2887f3d761162e8275a4cb894582      1
# 6d844eaed52347808654fd982a85fabc      1
# 24d2fc77ba145fe56620ed5a0479e38a      1
# 902a603cb12499d9813b9a5a183aa5e7      1
# d70562cdf840511963b3b15a111ce86b      1
# ffaa55486d290af4db0289f6dbec9720      1
# d2401b0dd9c6a5a25b177bec269480bd      1
# dc72c893d2863801cf40a525abd40213      1
# fbfc1034ba36cf2cfd971ddf7da165e0      1
# 55dca75021f8f8fd750b3cea65bead8a      1
# 6faf81bc05d26b1ba53d7fb569a31ead      1
# bb204313860e9a9728398e2e7a4f4513      1
# 35db923975632754866a93fdcac2b7d1      1
# 759f308dbb6d65157ceddc70e1979eff      1
# 031475f665780ca41ef28ac4e8545cff      1
# 5dcf08608ffe04bbfae98d6218298a4b      1
# fe92095a3352879f828b5bb24487c239      1
# 8c4fadd822b40ca92acd668cc5eb3946      1
# Name: UserId, Length: 259318, dtype: int64
# ==========================================================
# Column: Country
# 1      222309
# 40      86382
# 255     18231
# 14       2028
# 2         215
# 30        212
# 47         65
# 15         23
# 12         22
# 0          15
# 7          15
# 5          11
# 11         10
# 46          9
# 10          8
# 23          5
# 54          4
# 16          2
# 24          2
# 57          1
# 88          1
# 211         1
# 36          1
# 39          1
# 9           1
# 86          1
# 42          1
# 159         1
# 163         1
# 65          1
# Name: Country, dtype: int64
# ==========================================================
# Column: Device
# 1    311159
# 2     15509
# 0      2742
# 3       169
# Name: Device, dtype: int64
# ==========================================================
# Column: OS
# 1    303881
# 2     23118
# 0      2580
# Name: OS, dtype: int64
# ==========================================================
# Column: Status
# Completed        228971
# Not Completed    100608
# Name: Status, dtype: int64
# ==========================================================
# Column: State
# 35     88001
# 57     38726
# 160    27667
# 40     26604
# 36     24674
# 0      18406
# 33     17752
# 46     14821
# 14      7931
# 38      7085
# 39      5857
# 43      5503
# 31      4924
# 23      4747
# 2       4020
# 37      3286
# 49      3171
# 6       2872
# 48      2675
# 47      2362
# 12      2169
# 1       2044
# 7       1802
# 41      1723
# 45      1697
# 15      1418
# 50       985
# 42       911
# 24       515
# 44       487
#        ...
# 137        9
# 159        8
# 148        8
# 129        8
# 3          7
# 74         7
# 60         6
# 117        6
# 120        5
# 21         5
# 136        4
# 130        4
# 147        3
# 11         3
# 112        3
# 145        3
# 10         2
# 30         2
# 144        2
# 138        2
# 127        2
# 118        2
# 116        2
# 64         2
# 139        1
# 132        1
# 83         1
# 221        1
# 152        1
# 252        1
# Name: State, Length: 102, dtype: int64

# %%
num_cols = ['Country', 'Status']


for i in range(0,len(num_cols),2):
    if len(num_cols) > i+1:
        plt.figure(figsize=(20,7))
        plt.subplot(121)
        sns.countplot(num_cols[i],data = registration_df)
        plt.subplot(122)            
        sns.countplot(num_cols[i+1],data = registration_df)
        plt.tight_layout()
        plt.show()

    else:
        sns.countplot(num_cols[i],data = registration_df)

# %%
ax = sns.countplot('Device',data = registration_df)
ax.set_xticklabels(['Desktop(0)','Mobile(1)','Tablet(2)','TV(3)'], rotation='horizontal', fontsize=10)
# Out:
# [Text(0,0,'Desktop(0)'),
#  Text(0,0,'Mobile(1)'),
#  Text(0,0,'Tablet(2)'),
#  Text(0,0,'TV(3)')]

# %%
ax = sns.countplot('Device',data = registration_df)
ax.set_xticklabels(['Others(0)','Android(1)','iOS(2)'], rotation='horizontal', fontsize=10)
# Out:
# [Text(0,0,'Others(0)'), Text(0,0,'Android(1)'), Text(0,0,'iOS(2)')]

# %%
plt.figure(figsize=(40,15))
sns.set(font_scale = 1.5)
sns.countplot('State',data = registration_df, )

# %%
registration_df['UserId'].value_counts().describe()
# Out:
# count    259318.000000
# mean          1.270945
# std           1.357468
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max         546.000000
# Name: UserId, dtype: float64

# %%
forcasting_df = registration_df.groupby('Date').count()
forcasting_df = forcasting_df.reset_index()
plt.figure(figsize=(20,7))
sns.set(font_scale = 1)
plt.xticks(rotation=90);
ax = sns.pointplot(x = forcasting_df.Date, y = forcasting_df.UserId, label='Release Count')

# %%
df_applaunched = registration_df.copy()

df_applaunched['Date'] = pd.to_datetime(df_applaunched['Date'],format="%Y%m%d")
df_applaunched['month'] = df_applaunched['Date'].dt.strftime('%b')
df_applaunched['day_of_month']= df_applaunched['Date'].dt.day

#Grouping by month & day, aggregating based on count of users for each day of each month
df_groupedby_month_and_day = df_applaunched.groupby(by=['month','day_of_month']).count().reset_index()


#Plotting the stacked line chart for each day of each month
plt.figure(figsize=(16, 7))
sns.pointplot(x="day_of_month", y="UserId", hue="month", data=df_groupedby_month_and_day)
plt.xlabel("Day of Month")
plt.ylabel("No. of AppLaunches")
plt.title("VARIATION IN APP REGISTRATION DAILY FROM JAN TO JUNE")
plt.legend(loc='upper right')

# %%
sns.countplot(x='OS', hue='Device', data=registration_df)

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='Country', hue='Status', data=registration_df)

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='Device', hue='Status', data=registration_df)

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='OS', hue='Status', data=registration_df)

# %% [markdown]
# # Timestamp conversion for Registration

# %%
registration_df['Timestamp'] = registration_df.apply(make_timestamp, axis=1)

# %%
registration_df.head()
# Out:
#                              UserId      Date  Minute_Of_Day  Second  State  \
# 0  d168e2b924124feaad13eae44a68fce9  20170106              0       8     35
# 1  deed7490952a6746610ee2ee9fd219b7  20170106              0       8      7
# 2  13d9f55e297d7d9c219fbe9085e1006c  20170106              0      28     35
# 3  fccc2c0abf5afabf242a70df7b4c9e69  20170106              0      52     39
# 4  9ff982b29d78cefc8eb5a3ffb7fd2a5d  20170106              0      52     38
#
#    Country  Device  OS         Status  Timestamp
# 0        1       1   2      Completed 2017-01-06
# 1       40       1   1      Completed 2017-01-06
# 2        1       1   2      Completed 2017-01-06
# 3        1       1   1      Completed 2017-01-06
# 4        1       1   1  Not Completed 2017-01-06

# %% [markdown]
# <a id="eda-utm-visited"></a>
# # EDA for UTM Visited

# %%
#read the csv file into pandas dataframe
import pandas as pd
import seaborn as sns
UTM_Visited_df = pd.read_csv("./Data/UTMVisited.csv")

# %%
#view the first 5 rows of the dataset
UTM_Visited_df.head()
# Out:
#                              UserId      Date  Minute_Of_Day  Second  State  \
# 0  66d4abf4f3b733c27591b3f47c85eff7  20170106              0      52     37
# 1  1a40d7e5b34131b097fac80cf982241b  20170106              0      56     40
# 2  b7b3c1ce773a13b52d39429e305ea615  20170106              1      16     35
# 3  3f486a89433a02b96ab13b16c82e39fd  20170106              1      32     35
# 4  9ff982b29d78cefc8eb5a3ffb7fd2a5d  20170106              1      32     38
#
#    Country  Device  OS
# 0        1       1   1
# 1        1       1   1
# 2        1       1   1
# 3        1       1   1
# 4        1       1   1

# %%
#view the number of rows and columns in the dataset
UTM_Visited_df.shape
# Out:
# (495850, 8)

# %%
#view the datatypes of the columns in the dataset
UTM_Visited_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495850 entries, 0 to 495849
# Data columns (total 8 columns):
# UserId           495850 non-null object
# Date             495850 non-null int64
# Minute_Of_Day    495850 non-null int64
# Second           495850 non-null int64
# State            495850 non-null int64
# Country          495850 non-null int64
# Device           495850 non-null int64
# OS               495850 non-null int64
# dtypes: int64(7), object(1)
# memory usage: 30.3+ MB

# %%
#check for the number of missing values
UTM_Visited_df.isnull().sum()
# Out:
# UserId           0
# Date             0
# Minute_Of_Day    0
# Second           0
# State            0
# Country          0
# Device           0
# OS               0
# dtype: int64

# %%
##view the value counts of the Country column
UTM_Visited_df["Country"].value_counts()
# Out:
# 1      324892
# 40     139172
# 255     28337
# 14       1836
# 2         555
# 30        160
# 12        140
# 0         127
# 47         96
# 15         89
# 7          72
# 23         54
# 5          51
# 10         47
# 46         39
# 11         26
# 24         25
# 34         19
# 21         19
# 73         11
# 57         10
# 16         10
# 77          7
# 54          6
# 32          6
# 39          5
# 6           5
# 20          4
# 86          4
# 44          3
# 163         3
# 135         2
# 36          2
# 179         2
# 42          2
# 65          2
# 25          1
# 72          1
# 115         1
# 134         1
# 45          1
# 52          1
# 61          1
# 4           1
# 62          1
# 29          1
# Name: Country, dtype: int64

# %%
#view the value counts of the OS column
UTM_Visited_df["OS"].value_counts()
# Out:
# 1    483461
# 2     12338
# 0        51
# Name: OS, dtype: int64

# %%
#Exploring the 'Country' column of UTM Visited Data.
UTM_Visited_df_country = pd.DataFrame(UTM_Visited_df['Country'].value_counts())
#Selecting only the country which have high counts of users in UTM visited
UTM_Visited_df_country = UTM_Visited_df_country[UTM_Visited_df_country['Country']>50000]
#Visualizing using the bar plot
ax = sns.barplot(x=UTM_Visited_df_country.index,y=UTM_Visited_df_country['Country'])

# %%
#Exploring the 'State' column of UTM Visited Data.
UTM_Visited_df_state = pd.DataFrame(UTM_Visited_df['State'].value_counts())
#Selecting only the state which have high counts of users in UTM visited
UTM_Visited_df_state = UTM_Visited_df_state[UTM_Visited_df_state['State']>30000]
#Visualizing using the bar plot
ax = sns.barplot(x=UTM_Visited_df_state.index,y=UTM_Visited_df_state['State'])

# %%
##view the value counts of the State column
UTM_Visited_df["State"].value_counts()
# Out:
# 35     130943
# 57      46993
# 40      39612
# 160     39429
# 36      35398
# 33      33565
# 0       28472
# 46      22249
# 38      12957
# 14      12261
# 39       9189
# 31       8551
# 2        8537
# 43       7992
# 23       7738
# 48       6181
# 37       5543
# 47       4350
# 49       4081
# 6        4022
# 7        3462
# 12       2871
# 15       2439
# 45       2432
# 41       2055
# 1        1884
# 50       1540
# 42       1142
# 32        885
# 5         846
#         ...
# 130        11
# 252        11
# 60          9
# 120         9
# 21          9
# 117         8
# 112         7
# 147         6
# 149         5
# 83          5
# 144         4
# 64          4
# 139         4
# 221         3
# 76          3
# 85          3
# 61          3
# 30          3
# 19          3
# 118         3
# 136         3
# 127         3
# 66          2
# 101         2
# 140         1
# 116         1
# 79          1
# 145         1
# 132         1
# 152         1
# Name: State, Length: 111, dtype: int64

# %%
#Exploring the 'Country' column of UTM Visited Data.
UTM_Visited_df_device = pd.DataFrame(UTM_Visited_df['Device'].value_counts())
#Visualizing using the bar plot
ax = sns.barplot(x=UTM_Visited_df_device.index,y=UTM_Visited_df_device['Device'])
ax.set_xticklabels(['0(Desktop)','1(Mobile)','2(Tablet)','3(TV)'], rotation='horizontal', fontsize=10)
# Out:
# [Text(0,0,'0(Desktop)'),
#  Text(0,0,'1(Mobile)'),
#  Text(0,0,'2(Tablet)'),
#  Text(0,0,'3(TV)')]

# %%
#Exploring the 'OS' column of UTM Visited Data.
UTM_Visited_df_OS = pd.DataFrame(UTM_Visited_df['OS'].value_counts())
#Visualizing using the bar plot
ax = sns.barplot(x=UTM_Visited_df_OS.index,y=UTM_Visited_df_OS['OS'])
ax.set_xticklabels(['0: Others', '1: Android', '2: iOS', '3: Windows','4: Mac', '5: BlackBerry', '6: Linux'], rotation='horizontal', fontsize=10)
# Out:
# [Text(0,0,'0: Others'), Text(0,0,'1: Android'), Text(0,0,'2: iOS')]

# %%
import seaborn as sns
UTM_Visited_df['Date'] = pd.to_datetime(UTM_Visited_df['Date'],format="%Y%m%d")
UTM_Visited_df['month'] = UTM_Visited_df['Date'].dt.strftime('%b')
UTM_Visited_df['day_of_month']= UTM_Visited_df['Date'].dt.day

#Grouping by month & day, aggregating based on count of users for each day of each month
df_groupedby_month_and_day = UTM_Visited_df.groupby(by=['month','day_of_month']).count().reset_index()


#Plotting the stacked line chart for each day of each month
plt.figure(figsize=(16, 7))
sns.pointplot(x="day_of_month", y="UserId", hue="month", data=df_groupedby_month_and_day)
plt.xlabel("Day of Month")
plt.ylabel("No. of UTMVisited")
plt.title("VARIATION IN UTM visited DAILY FROM JAN TO MAY")
plt.legend(loc='upper right')

# %% [markdown]
# <a id="eda-video-details"></a>
# # EDA for Video Details

# %%
df_video_details = pd.read_csv('./Data/VideoDetails.csv')

# %%
df_video_details.head()
# Out:
#                              UserId      Date  Minute_Of_Day  Second  State  \
# 0  dc93d200565e5bf6e6fc55adb1c5ba06  20170106              0       4     35
# 1  12060efd8b68ea562b265d0129a8af1f  20170106              0      16     35
# 2  9151ab2a901458f27e36548d4a8dc011  20170106              0      20      0
# 3  1faf0ce0b98e02e1568702f516f01a78  20170106              0      20     35
# 4  435d41ae019cb8db785483793859c9a8  20170106              0      20     35
#
#       Genre Category ProgramType  Country  Device  OS  \
# 0    Drama      vod    TV Shows         1       2   1
# 1   Horror      vod      Movies         1       1   1
# 2    Drama      vod    TV Shows       255       1   1
# 3    Drama      vod    TV Shows         1       1   1
# 4    Anime      vod    TV Shows         1       1   1
#
#                             VideoId
# 0  1f2dc23e0d2415353982cfa38cbaf983
# 1  6c95441f239cebf9930ac5932cc84a7f
# 2  1af000794c63fa2722e22af609ff572c
# 3  f053c42e98d50e06532ce8d65afb3ab3
# 4  2a9d984659afc14f801548dd71ddad0e

# %%
df_video_details = df_video_details[df_video_details['ProgramType']!='  ']

# %%
df_video_details['ProgramType'].value_counts()
# Out:
#  TV Shows     3117020
#  Movies        398975
#  Channels      179228
# Name: ProgramType, dtype: int64

# %%
df_video_details['Date'] = df_video_details.apply(make_timestamp,axis=1)

# %%
df_video_details['Date'].head()

# %%
sns.countplot(x=df_video_details['ProgramType'],hue=df_video_details['Category'])

# %%
ax = sns.countplot(x=df_video_details['Device'],hue=df_video_details['Category'])
ax.set_xticklabels(['Desktop','Mobile','Tablet','TV'],rotation='horizontal',fontsize=10)

# %%
df_video_details.OS.value_counts()

# %%
ax = sns.countplot(x=df_video_details['Device'],hue=df_video_details['OS'])
ax.set_xticklabels(['Desktop','Mobile','Tablet','TV'],rotation='horizontal',fontsize=10)

# %%
new_labels = ['label 1', 'label 2']
for t, l in zip(ax._legend.texts, new_labels): t.set_text(l)

sns.plt.show()

# %%
#Starting with date & time of day columns of VideoDetails data
#Splitting the date column into month & day
df_video_details['month'] = df_video_details['Date'].dt.strftime('%b')
df_video_details['day_of_month']= df_video_details['Date'].dt.day

#Grouping by month & day, aggregating based on count of video details viewed for each day of each month
df_groupedby_month_and_day = df_video_details.groupby(by=['month','day_of_month']).count().reset_index()

#Plotting the stacked line chart for each day of each month
plt.figure(figsize=(16, 7))
sns.pointplot(x="day_of_month", y="UserId", hue="month", data=df_groupedby_month_and_day)
plt.xlabel("Day of Month")
plt.ylabel("No. of VideoViewed")
plt.title("VARIATION IN VIDEOS DETAILS VIEWED FROM JAN TO MAY")
plt.legend(loc='upper right')

# %% [markdown]
# <a id="eda-video-started"></a>
# # EDA for Video Started

# %%
df_video_started = pd.read_csv('./Data/VideoStarted.csv')

# %%
df_video_started.head()

# %%
df_video_started['Date'] = df_video_started.apply(make_timestamp,axis=1)

# %%
df_video_started['Date'].head()

# %%
sns.countplot(x=df_video_started['ProgramType'],hue=df_video_started['Category'])

# %%
ax = sns.countplot(x=df_video_started['Device'],hue=df_video_started['Category'])
ax.set_xticklabels(['Desktop','Mobile','Tablet','TV'],rotation='horizontal',fontsize=10)

# %%
df_video_started.OS.value_counts()

# %%
ax = sns.countplot(x=df_video_started['Device'],hue=df_video_started['OS'])
ax.set_xticklabels(['Desktop','Mobile','Tablet','TV'],rotation='horizontal',fontsize=10)

# %%
#Starting with date & time of day columns of VideoDetails data
#Splitting the date column into month & day
df_video_started['month'] = df_video_started['Date'].dt.strftime('%b')
df_video_started['day_of_month']= df_video_started['Date'].dt.day

#Grouping by month & day, aggregating based on count of video started viewed for each day of each month
df_groupedby_month_and_day = df_video_started.groupby(by=['month','day_of_month']).count().reset_index()

#Plotting the stacked line chart for each day of each month
plt.figure(figsize=(16, 7))
sns.pointplot(x="day_of_month", y="UserId", hue="month", data=df_groupedby_month_and_day)
plt.xlabel("Day of Month")
plt.ylabel("No. of VideoViewed")
plt.title("VARIATION IN VIDEOS STARTED FROM JAN TO MAY")
plt.legend(loc='upper right')

# %% [markdown]
# # Combining all dataframes

# %%
df_consolidated = pd.DataFrame()

# %%
df_applaunched_grouped = df_applaunched.groupby('UserId').count()
columns = df_applaunched_grouped.columns.drop(['Minute_Of_Day', 'Second', 'State', 'Country', 'Device', 'OS'])

df_applaunched_grouped = df_applaunched_grouped[columns]
df_applaunched_grouped.columns = ['app_launched_count']

df_consolidated = df_applaunched_grouped.copy()

registration_df_grouped = registration_df.groupby('UserId').count()
registration_df_grouped = registration_df_grouped[['Date']]
registration_df_grouped.columns = ['registration_count']
df_consolidated = pd.concat([df_consolidated, registration_df_grouped], axis=1)

app_uninstalled_df_grouped = app_uninstalled_df.groupby('UserId').count()
app_uninstalled_df_grouped = app_uninstalled_df_grouped[['Date']]
app_uninstalled_df_grouped.columns = ['uninstalled_count']
df_consolidated = pd.concat([df_consolidated, app_uninstalled_df_grouped], axis=1)

UTM_Visited_df_grouped = UTM_Visited_df.groupby('UserId').count()
UTM_Visited_df_grouped = UTM_Visited_df_grouped[['Date']]
UTM_Visited_df_grouped.columns = ['utm_visited_count']
df_consolidated = pd.concat([df_consolidated, UTM_Visited_df_grouped], axis=1)

df_video_details_grouped = df_video_details.groupby('UserId').count()
df_video_details_grouped = df_video_details_grouped[['Date']]
df_video_details_grouped.columns = ['video_details_count']
df_consolidated = pd.concat([df_consolidated, df_video_details_grouped], axis=1)

df_video_started_grouped = df_video_started.groupby('UserId').count()
df_video_started_grouped = df_video_started_grouped[['Date']]
df_video_started_grouped.columns = ['video_started_grouped']
df_consolidated = pd.concat([df_consolidated, df_video_started_grouped], axis=1)
# Out:
# /Users/Clyde/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
